# %% [markdown]
# # Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import os
os.getcwd()
# Out:
# '/Users/abhishek/Desktop/Python Data/2. Pandas Basic Exercises'

# %% [markdown]
# ### Step 2. Import the dataset *chipotle.tsv*

# %%
pd.read_table("/Users/abhishek/Desktop/Python Data/2. Pandas Basic Exercises/Exercise Data Files/Pandas Exercise Filtering Sorting Files/chipotle.tsv",sep="\t")
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_table("/Users/abhishek/Desktop/Python Data/2. Pandas Basic Exercises/Exercise Data Files/Pandas Exercise Filtering Sorting Files/chipotle.tsv",sep="\t")
chipo.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?
#
# Use `str` attribute to remove the $ sign and convert the column to proper numeric type data before filtering.

# %%
chipo.item_price = chipo.item_price.str.replace("$","")
chipo.item_price = pd.to_numeric(chipo.item_price,errors = "coerce")

# %%
sub1 = chipo.loc[chipo.item_price>10].reset_index(drop = True)
sub1
# Out:
#       order_id  quantity           item_name  \
# 0            2         2        Chicken Bowl
# 1            3         1        Chicken Bowl
# 2            4         1       Steak Burrito
# 3            7         1        Chicken Bowl
# 4           12         1     Chicken Burrito
# ...        ...       ...                 ...
# 1125      1830         1       Steak Burrito
# 1126      1830         1      Veggie Burrito
# 1127      1833         1       Steak Burrito
# 1128      1833         1       Steak Burrito
# 1129      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 1     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 2     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 3     [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 4     [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %%
chipo.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %% [markdown]
# ### Step 5. What is the price of each item?
#
# print a data frame with only two columns `item_name` and `item_price`

# %%
sub2 = chipo.loc[:,["item_name","item_price"]].reset_index(drop=True)
sub2 = sub2.loc[-sub2.duplicated(),]
sub2
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4237                    Chips and Guacamole        8.50
# 4354                       Steak Soft Tacos       18.50
# 4489                    Chips and Guacamole       17.80
# 4509                                  Chips        1.99
# 4510                          Barbacoa Bowl       11.49
#
# [209 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
sort2 = chipo.sort_values(by = "item_name")
sort2
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
sort1 = chipo.sort_values(by = "item_price",ascending = False)
sort1
#15 is the quantity of the most expensive item ordered
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
# ...        ...       ...                           ...
# 3936      1578         1                   Canned Soda
# 2922      1162         1                 Bottled Water
# 1396       567         1                   Canned Soda
# 2562      1014         1                   Canned Soda
# 1457       591         1                   Canned Soda
#
#                                      choice_description  item_price
# 3598                                                NaN       44.25
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       35.00
# ...

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
filter1 = chipo.loc[chipo.item_name == "Veggie Salad Bowl"].reset_index(drop = True)
filter1
#Veggie Salad Bowl is ordered 18 times
# Out:
#     order_id  quantity          item_name  \
# 0         83         1  Veggie Salad Bowl
# 1        128         1  Veggie Salad Bowl
# 2        195         1  Veggie Salad Bowl
# 3        207         1  Veggie Salad Bowl
# 4        394         1  Veggie Salad Bowl
# 5        536         1  Veggie Salad Bowl
# 6        760         1  Veggie Salad Bowl
# 7        869         1  Veggie Salad Bowl
# 8        896         1  Veggie Salad Bowl
# 9        913         1  Veggie Salad Bowl
# 10      1066         1  Veggie Salad Bowl
# 11      1289         1  Veggie Salad Bowl
# 12      1321         1  Veggie Salad Bowl
# 13      1646         1  Veggie Salad Bowl
# 14      1677         1  Veggie Salad Bowl
# 15      1700         1  Veggie Salad Bowl
# 16      1805         1  Veggie Salad Bowl
# 17      1818         1  Veggie Salad Bowl
#
#                                    choice_description  item_price
# 0   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# ...

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
filter2 = chipo.loc[(chipo.quantity > 1) & (chipo.item_name == "Canned Soda")].reset_index(drop = True)
filter2
# 20 times People have ordered more than one canned soda
# Out:
#     order_id  quantity    item_name choice_description  item_price
# 0          9         2  Canned Soda           [Sprite]        2.18
# 1         23         2  Canned Soda     [Mountain Dew]        2.18
# 2         73         2  Canned Soda        [Diet Coke]        2.18
# 3         76         2  Canned Soda  [Diet Dr. Pepper]        2.18
# 4        150         2  Canned Soda        [Diet Coke]        2.18
# 5        151         2  Canned Soda        [Coca Cola]        2.18
# 6        287         2  Canned Soda        [Coca Cola]        2.18
# 7        288         2  Canned Soda        [Coca Cola]        2.18
# 8        376         2  Canned Soda     [Mountain Dew]        2.18
# 9        450         2  Canned Soda       [Dr. Pepper]        2.18
# 10       450         2  Canned Soda        [Coca Cola]        2.18
# 11       787         2  Canned Soda       [Dr. Pepper]        2.18
# 12       859         2  Canned Soda        [Diet Coke]        2.18
# ...
