# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
Data = pd.read_excel("Online_rental_clean_data.xlsx")

# %%
Data.head(5)
# Out:
#    Age  Marriage_Status  Home_type  Home_furnishing           City  \
# 0   30                1          1                1        Lucknow
# 1   24                1          0                1      Bangalore
# 2   35                1          1                1        Lucknow
# 3   29                1          1                1          Delhi
# 4   25                1          1                1  Charkhi Dadri
#
#   Online_Shopping  Shopping_Comfort_Online rented_past Rent_furntiture  \
# 0             Yes                        5          No              No
# 1             Yes                        5         Yes             Yes
# 2             Yes                        5         Yes              No
# 3             Yes                        5          No           Maybe
# 4             Yes                        5          No           Maybe
#
#   COD_rent Free_Shipping_rent Repair_Free_rent Replacement_Delivery_Rent  \
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        34 non-null     int64
#  1   Marriage_Status            34 non-null     int64
#  2   Home_type                  34 non-null     int64
#  3   Home_furnishing            34 non-null     int64
#  4   City                       34 non-null     object
#  5   Online_Shopping            34 non-null     object
#  6   Shopping_Comfort_Online    34 non-null     int64
#  7   rented_past                34 non-null     object
#  8   Rent_furntiture            34 non-null     object
#  9   COD_rent                   34 non-null     object
#  10  Free_Shipping_rent         34 non-null     object
#  11  Repair_Free_rent           34 non-null     object
#  12  Replacement_Delivery_Rent  34 non-null     object
# ...

# %%
list(Data.columns)
# Out:
# ['Age',
#  'Marriage_Status',
#  'Home_type',
#  'Home_furnishing',
#  'City',
#  'Online_Shopping',
#  'Shopping_Comfort_Online',
#  'rented_past',
#  'Rent_furntiture',
#  'COD_rent',
#  'Free_Shipping_rent',
#  'Repair_Free_rent',
#  'Replacement_Delivery_Rent',
#  'Installation_rent',
#  'Monthly_rent',
#  'QuickDelivery_rent',
#  'Rental_website_visit']

# %%
Bachelors_Data = Data.loc[Data.Marriage_Status==1]
Bachelors_Data.head(6)
# Out:
#    Age  Marriage_Status  Home_type  Home_furnishing           City  \
# 0   30                1          1                1        Lucknow
# 1   24                1          0                1      Bangalore
# 2   35                1          1                1        Lucknow
# 3   29                1          1                1          Delhi
# 4   25                1          1                1  Charkhi Dadri
# 5   24                1          1                1          Delhi
#
#   Online_Shopping  Shopping_Comfort_Online rented_past Rent_furntiture  \
# 0             Yes                        5          No              No
# 1             Yes                        5         Yes             Yes
# 2             Yes                        5         Yes              No
# 3             Yes                        5          No           Maybe
# 4             Yes                        5          No           Maybe
# ...

# %%
Bachelors_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 0 to 33
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        22 non-null     int64
#  1   Marriage_Status            22 non-null     int64
#  2   Home_type                  22 non-null     int64
#  3   Home_furnishing            22 non-null     int64
#  4   City                       22 non-null     object
#  5   Online_Shopping            22 non-null     object
#  6   Shopping_Comfort_Online    22 non-null     int64
#  7   rented_past                22 non-null     object
#  8   Rent_furntiture            22 non-null     object
#  9   COD_rent                   22 non-null     object
#  10  Free_Shipping_rent         22 non-null     object
#  11  Repair_Free_rent           22 non-null     object
#  12  Replacement_Delivery_Rent  22 non-null     object
# ...

# %%
Bachelors_own_fur_semi = Bachelors_Data.loc[(Bachelors_Data.Home_type==1) & (Bachelors_Data.Home_furnishing==1)]
Bachelors_own_fur_semi.head(2)
Bachelors_own_fur_semi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        10 non-null     int64
#  1   Marriage_Status            10 non-null     int64
#  2   Home_type                  10 non-null     int64
#  3   Home_furnishing            10 non-null     int64
#  4   City                       10 non-null     object
#  5   Online_Shopping            10 non-null     object
#  6   Shopping_Comfort_Online    10 non-null     int64
#  7   rented_past                10 non-null     object
#  8   Rent_furntiture            10 non-null     object
#  9   COD_rent                   10 non-null     object
#  10  Free_Shipping_rent         10 non-null     object
#  11  Repair_Free_rent           10 non-null     object
#  12  Replacement_Delivery_Rent  10 non-null     object
# ...

# %%
for i in Bachelors_own_fur_semi.columns:
    Bachelors_own_fur_semi[i].hist()
    plt.xlabel(str(i))
    plt.show()

# %% [markdown]
# 1. Drilled down the data to bachlors who owns a house and lives independetnyl & want fully furnished house (10 entries out of 34 entries
# 2. Majority of the people belong to 24-34 Age in this group
# 3. All of them have done online shopping in the past
# 4. 90% of the popluation is comfortable in shopping online
# 5. 80% of this group has never rented anything form online in the past
# 6. 70% of this group may or may not rent furniture online
# 7. More than 60% of the population in this group will rent furntiure if they are given the option of COD
# 8. Everyone will rent the furniture if they are provided with free shipping of the furniture across the country, free repairing, replacement of the furnitutre if foud faulty at the time of delivery,to pay the rent on monthly basis, delivery in 48 hrs
# 9. 90% of this group will rent the furntiure if installation is done by the service provider
# 10. 70% has visited furniture rental website in the past.

# %%
Bachelors_rent_fur_semi = Bachelors_Data.loc[(Bachelors_Data.Home_type==0) & (Bachelors_Data.Home_furnishing==1)]
Bachelors_rent_fur_semi
Bachelors_rent_fur_semi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 1 to 30
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        9 non-null      int64
#  1   Marriage_Status            9 non-null      int64
#  2   Home_type                  9 non-null      int64
#  3   Home_furnishing            9 non-null      int64
#  4   City                       9 non-null      object
#  5   Online_Shopping            9 non-null      object
#  6   Shopping_Comfort_Online    9 non-null      int64
#  7   rented_past                9 non-null      object
#  8   Rent_furntiture            9 non-null      object
#  9   COD_rent                   9 non-null      object
#  10  Free_Shipping_rent         9 non-null      object
#  11  Repair_Free_rent           9 non-null      object
#  12  Replacement_Delivery_Rent  9 non-null      object
# ...

# %%
for i in Bachelors_rent_fur_semi.columns:
    Bachelors_rent_fur_semi[i].hist()
    plt.xlabel(str(i))
    plt.show()

# %% [markdown]
# 1. 88% of the people in this segment lies in the age range of 24-26
# 2. All of them are bachelors, living in an rented house who want there house to be fully furnsihed
# 3. All of them has done online shopping in the past
# 4. More than 88% of the audience is comforatble in online shopping
# 5. 66% people of this has segment has never rented anything online
# 6. 45% of the population of this group will rent the furniture online other 45% is skepctical about it
# 7. 78% will rent the furniture if COD option is given to them
# 8. 100% of this segment will rent the furniture online if they get free shipping of the furniture, free repairing, replacement of the furniture if its faulty at the time of delivery, installation is done by the provider, monthly payment for it, delivered in next 48 hrs.
# 9. 88% of this segment have visited the renatl website in the past

# %%
Newly_wed = Data.loc[Data.Marriage_Status==3]
Newly_wed
# Out:
#     Age  Marriage_Status  Home_type  Home_furnishing       City  \
# 6    22                3          1                1  Bangalore
# 21   45                3          1                2  Bangalore
# 24   26                3          0                1      Delhi
#
#    Online_Shopping  Shopping_Comfort_Online rented_past Rent_furntiture  \
# 6              Yes                        4          No              No
# 21             Yes                        4          No             Yes
# 24             Yes                        5         Yes             Yes
#
#    COD_rent Free_Shipping_rent Repair_Free_rent Replacement_Delivery_Rent  \
# 6        No                Yes               No                       Yes
# 21      Yes                Yes              Yes                       Yes
# 24      Yes                Yes              Yes                       Yes
#
#    Installation_rent Monthly_rent QuickDelivery_rent Rental_website_visit
# ...

# %%
for i in Bachelors_rent_fur_semi.columns:
    Bachelors_rent_fur_semi[i].hist()
    plt.xlabel(str(i))
    plt.show()
